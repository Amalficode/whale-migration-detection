# %% [markdown]
# # 🐋 Whale Migration Detection — Notebook
#
# Этот ноутбук служит шаблоном. Замените его своим рабочим ноутбуком
# из Google Colab, в котором вы:
# - загружаете изображения китов,
# - отправляете их в workflow Roboflow,
# - визуализируете результаты и сохраняете их в папку `results/`.
